# %%
import matplotlib.pyplot as plt

# %%
arc_mean=0.47511606365829384
dep_mean= 0.4644662689135275
arc_std= 0.056310312944484506
dep_std= 0.05575102700274893

# %%
arc = [arc_mean,arc_std]

# %%
prob = [0.5312805474095796,0.4696969696969697,0.6362053959965187,0.45640074211502785,0.5872832369942197,0.7490272373540856]

# %%
plt.plot(prob)
plt.ylabel('Prob')
plt.xlabel('Experiment index')
plt.savefig('exparc2.png')
plt.show()
